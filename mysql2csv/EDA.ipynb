# %% [markdown]
# # Notebook para Exploratory Data Analysis dos dados da plataforma Sucupira

# %%
import pandas as pd
import numpy as np
import pymysql as pms
import matplotlib.pyplot as plt

# %%
tab = pd.read_csv('sucupirafilter.csv',sep=';')

# %%
tab.head()
# Out:
#    (area_avaliacao) id                              (area_avaliacao) nome  \
# 0                  149  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...
# 1                  149  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...
# 2                  149  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...
# 3                  149  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...
# 4                  149  ADMINISTRAÇÃO PÚBLICA E DE EMPRESAS, CIÊNCIAS ...
#
#    (area_avaliacao) codigo  (area_conhecimento) id (area_conhecimento) nome  \
# 0                       27                       2            ADMINISTRAÇÃO
# 1                       27                       2            ADMINISTRAÇÃO
# 2                       27                       2            ADMINISTRAÇÃO
# 3                       27                       2            ADMINISTRAÇÃO
# 4                       27                       2            ADMINISTRAÇÃO
#
#    (area_conhecimento) codigo  (area_conhecimento) area_avaliacao_id  \
# 0                    60200006                                    149
# 1                    60200006                                    149
# 2                    60200006                                    149
# 3                    60200006                                    149
# 4                    60200006                                    149
#
#    (programa) id                              (programa) nome  \
# 0             87       ADMINISTRAÇÃO PÚBLICA EM REDE NACIONAL
# 1             88                                ADMINISTRAÇÃO
# 2             89                                Administração
# 3             90  ADMINISTRAÇÃO DAS MICRO E PEQUENAS EMPRESAS
# 4             91  ADMINISTRAÇÃO DAS MICRO E PEQUENAS EMPRESAS
#
#   (programa) codigo         ...          \
# 0     53045009001P3         ...
# 1     32020015008P9         ...
# 2     52016013002P3         ...
# 3     33149011003P8         ...
# 4     33149011001P5         ...
#
#                                    (instituicao) url  \
# 0                         http://portal.ufgd.edu.br/
# 1                         http://www.ppga.cefetmg.br
# 2             http://www.unialfa.com.br/mestrado/adm
# 3  http://www.faccamp.br/new/doutorado/administracao
# 4  http://www.faccamp.br/new/doutorado/administracao
#
#    (instituicao) coordenadas  (curso) id  \
# 0        -22.19446 -54.93025         125
# 1         -19.9316 -43.98497         126
# 2        -16.64133 -49.30773         127
# 3         -15.78791 -47.8782         128
# 4         -15.78791 -47.8782         129
#
#                                   (curso) nome  (curso) situacao  \
# 0       ADMINISTRAÇÃO PÚBLICA EM REDE NACIONAL  EM FUNCIONAMENTO
# 1                                ADMINISTRAÇÃO  EM FUNCIONAMENTO
# 2                                Administração  EM FUNCIONAMENTO
# 3  ADMINISTRAÇÃO DAS MICRO E PEQUENAS EMPRESAS  EM FUNCIONAMENTO
# 4  ADMINISTRAÇÃO DAS MICRO E PEQUENAS EMPRESAS  EM FUNCIONAMENTO
#
#            (curso) nivel (curso) nota_curso (curso) data_reconhecimento  \
# 0  Mestrado Profissional                  3                  23/04/2013
# 1               Mestrado                  3                  12/12/2014
# 2  Mestrado Profissional                  3                  23/04/2012
# 3              Doutorado                  4                  26/10/2016
# 4  Mestrado Profissional                  4                  16/09/2008
#
#   (curso) data_inicio (curso) programa_id
# 0          01/07/2014                  87
# 1          03/08/2015                  88
# 2          01/08/2012                  89
# 3          17/02/2017                  90
# 4          01/01/2009                  91
#
# [5 rows x 34 columns]

# %%
tab.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 352 entries, 0 to 351
# Data columns (total 34 columns):
# (area_avaliacao) id                      352 non-null int64
# (area_avaliacao) nome                    352 non-null object
# (area_avaliacao) codigo                  352 non-null int64
# (area_conhecimento) id                   352 non-null int64
# (area_conhecimento) nome                 352 non-null object
# (area_conhecimento) codigo               352 non-null int64
# (area_conhecimento) area_avaliacao_id    352 non-null int64
# (programa) id                            352 non-null int64
# (programa) nome                          352 non-null object
# (programa) codigo                        352 non-null object
# (programa) uf                            352 non-null object
# (programa) area_conhecimento_id          352 non-null int64
# (programa) instituicao_id                352 non-null int64
# (instituicao) id                         352 non-null int64
# (instituicao) nome                       352 non-null object
# (instituicao) codigo                     352 non-null int64
# (instituicao) acronimo                   352 non-null object
# (instituicao) endereco                   352 non-null object
# (instituicao) distrito                   352 non-null object
# (instituicao) cidade                     352 non-null object
# (instituicao) estado                     352 non-null object
# (instituicao) tipo                       352 non-null object
# (instituicao) cep                        352 non-null object
# (instituicao) caixa_postal               352 non-null object
# (instituicao) url                        352 non-null object
# (instituicao) coordenadas                352 non-null object
# (curso) id                               352 non-null int64
# (curso) nome                             352 non-null object
# (curso) situacao                         352 non-null object
# (curso) nivel                            352 non-null object
# (curso) nota_curso                       352 non-null object
# (curso) data_reconhecimento              352 non-null object
# (curso) data_inicio                      352 non-null object
# (curso) programa_id                      352 non-null int64
# dtypes: int64(12), object(22)
# memory usage: 93.6+ KB

# %%
tab['(curso) nota_curso'].value_counts()
# Out:
# 4    121
# 3    115
# 5     74
# A     17
# 6     14
# 7     10
# 2      1
# Name: (curso) nota_curso, dtype: int64

# %% [markdown]
# Inconsistência no dataset temos um 17 valores de 'A'

# %% [markdown]
# __(Tarefa 1) - Resolver como tratar estes A's__

# %%
tab.describe()
# Out:
#        (area_avaliacao) id  (area_avaliacao) codigo  (area_conhecimento) id  \
# count            352.00000               352.000000              352.000000
# mean             153.93750                26.838068               11.332386
# std               10.66301                 8.770218               19.676595
# min              149.00000                 1.000000                2.000000
# 25%              149.00000                27.000000                2.000000
# 50%              149.00000                27.000000                2.000000
# 75%              153.00000                27.000000                9.000000
# max              197.00000                50.000000               84.000000
#
#        (area_conhecimento) codigo  (area_conhecimento) area_avaliacao_id  \
# count                3.520000e+02                              352.00000
# mean                 5.779063e+07                              153.93750
# std                  1.458009e+07                               10.66301
# min                  1.010001e+07                              149.00000
# 25%                  6.020001e+07                              149.00000
# 50%                  6.020001e+07                              149.00000
# 75%                  6.020001e+07                              153.00000
# max                  9.050001e+07                              197.00000
#
#        (programa) id  (programa) area_conhecimento_id  \
# count     352.000000                       352.000000
# mean      217.968750                        11.332386
# std        74.959755                        19.676595
# min        87.000000                         2.000000
# 25%       154.000000                         2.000000
# 50%       216.500000                         2.000000
# 75%       282.000000                         9.000000
# max       353.000000                        84.000000
#
#        (programa) instituicao_id  (instituicao) id  (instituicao) codigo  \
# count                 352.000000        352.000000            352.000000
# mean                  163.207386        163.207386         337079.846591
# std                    63.508212         63.508212          18264.008890
# min                    72.000000         72.000000           2981.000000
# 25%                   116.000000        116.000000         338440.000000
# 50%                   149.500000        149.500000         338689.000000
# 75%                   196.000000        196.000000         339030.000000
# max                   331.000000        331.000000         341393.000000
#
#        (curso) id  (curso) programa_id
# count  352.000000           352.000000
# mean   300.500000           217.968750
# std    101.757883            74.959755
# min    125.000000            87.000000
# 25%    212.750000           154.000000
# 50%    300.500000           216.500000
# 75%    388.250000           282.000000
# max    476.000000           353.000000

# %% [markdown]
# Todos os dados númericos acima se tratam de identificadores, no caso '.describe()' não faria sentido.

# %% [markdown]
# __Parecem existir alguns valores '-' nas colunas de datas, constituindo assim missing values__

# %%
datas =tab[tab.columns[tab.columns.str.contains('data')]].replace('-',np.nan).dropna()
for col in datas :
    datas[col] = pd.to_datetime(datas[cols])
    
datas.dtypes
# Out:
# (curso) data_reconhecimento    datetime64[ns]
# (curso) data_inicio            datetime64[ns]
# dtype: object

# %%
datas
# Out:
#     (curso) data_reconhecimento (curso) data_inicio
# 0                    2014-01-07          2014-01-07
# 1                    2015-03-08          2015-03-08
# 2                    2012-01-08          2012-01-08
# 3                    2017-02-17          2017-02-17
# 4                    2009-01-01          2009-01-01
# 5                    2014-03-03          2014-03-03
# 6                    2017-08-31          2017-08-31
# 7                    2011-01-01          2011-01-01
# 8                    1999-01-01          1999-01-01
# 9                    2007-01-01          2007-01-01
# 10                   2011-01-01          2011-01-01
# 11                   2011-01-01          2011-01-01
# 12                   2005-01-01          2005-01-01
# 13                   2009-01-01          2009-01-01
# 14                   2010-01-01          2010-01-01
# 15                   2014-01-01          2014-01-01
# 16                   2015-03-16          2015-03-16
# 17                   2005-01-01          2005-01-01
# 18                   1999-01-01          1999-01-01
# 19                   2015-12-17          2015-12-17
# 20                   2014-07-03          2014-07-03
# 21                   2016-02-15          2016-02-15
# 22                   2014-01-01          2014-01-01
# 23                   2000-01-01          2000-01-01
# 24                   2015-07-08          2015-07-08
# 25                   2017-01-25          2017-01-25
# 26                   2016-07-28          2016-07-28
# 27                   1974-01-01          1974-01-01
# 32                   2002-01-01          2002-01-01
# 33                   2009-01-01          2009-01-01
# ..                          ...                 ...
# 316                  2013-01-01          2013-01-01
# 317                  2015-07-30          2015-07-30
# 318                  2015-05-14          2015-05-14
# 319                  2012-01-01          2012-01-01
# 320                  2012-01-01          2012-01-01
# 321                  1994-01-01          1994-01-01
# 323                  2011-01-01          2011-01-01
# 324                  2002-01-01          2002-01-01
# 325                  2010-01-01          2010-01-01
# 327                  2013-01-08          2013-01-08
# 328                  2009-01-01          2009-01-01
# 329                  2015-01-02          2015-01-02
# 331                  2015-10-03          2015-10-03
# 334                  2008-01-01          2008-01-01
# 335                  2017-03-04          2017-03-04
# 336                  2000-01-01          2000-01-01
# 337                  2000-01-01          2000-01-01
# 338                  2017-04-04          2017-04-04
# 339                  2014-05-26          2014-05-26
# 340                  2013-01-01          2013-01-01
# 342                  2015-02-03          2015-02-03
# 343                  2003-01-01          2003-01-01
# 344                  1993-01-01          1993-01-01
# 345                  2013-01-01          2013-01-01
# 346                  2015-10-08          2015-10-08
# 347                  2017-04-05          2017-04-05
# 348                  2009-01-01          2009-01-01
# 349                  2013-01-01          2013-01-01
# 350                  2004-01-01          2004-01-01
# 351                  2014-10-03          2014-10-03
#
# [293 rows x 2 columns]

# %% [markdown]
# # Realizar inner join com o primeiro data frame?
